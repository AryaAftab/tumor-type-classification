# %% [markdown]
# ## Import necessary libraries

# %%
import os
from glob import glob
from tqdm.notebook import tqdm
import pickle


import cv2
import numpy as np
import matplotlib.pyplot as plt


import sklearn
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

import utils 
import tensorflow as tf

## feature extractors
from SimpleITK import GetImageFromArray
from radiomics import glrlm, glcm, gldm

# %%
import logging
# set level for all classes
logger = logging.getLogger("radiomics")
logger.setLevel(logging.ERROR)

# %%
## Consistently create same random numpy array
np.random.seed(42)

# %% [markdown]
# ## Define path of prepared data

# %%
window_size = (7,7)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

classes = ["benign", "malignant", "normal"]

saved_directory = "prepared_data"
saved_image_filename = "image_with_mask_label.pickle"
saved_nakagami_filename = f"nakagami_features_window_{window_size[0]}x{window_size[1]}.pickle"

result_path = "results"
os.makedirs(result_path, exist_ok=True)

# %% [markdown]
# ## Load Data

# %%
with open(os.path.join(saved_directory, saved_image_filename), 'rb') as handle:
    data = pickle.load(handle)
    
with open(os.path.join(saved_directory, saved_nakagami_filename), 'rb') as handle:
    nakagami_maps = pickle.load(handle)

# %%
N_labels = {
    'benign': 0,
    'malignant': 0,
    'normal': 0
}

for datum in data:
    label = datum["label"]
    if label == 0 :
        N_labels["benign"] += 1
    elif label == 1:
        N_labels["malignant"] += 1
    elif label ==2:
        N_labels["normal"] += 1
    else:
        raise ValueError('Label not valid!')

# %%
N_labels
# Out:
# {'benign': 437, 'malignant': 210, 'normal': 133}

# %%
index = 437

plt.figure()
plt.imshow(data[index]["image"] * data[index]["mask"])

# %% [markdown]
# ## Extract GLDM, GLCM, GLRLM, and Nakagami features

# %%
glcmFeat = []
labels = []

for datum in tqdm(data[:(N_labels["benign"] + N_labels["malignant"])]): 
    
    datum_image = datum["image"].copy()
    datum_mask = datum["mask"].copy()
    
    glcmFeatures = glcm.RadiomicsGLCM(GetImageFromArray(datum_image),
                                      GetImageFromArray(datum_mask),
                                      verbose=False)
    
    
    glcmFeat.append(glcmFeatures.execute())
    
    labels.append(datum["label"])


extracted_glcm_features = []
keys = list(glcmFeat[0].keys())

for datum in glcmFeat:
    buff = []
    for key in keys:
        buff.append(datum[key])

    extracted_glcm_features.append(buff)

extracted_glcm_features = np.array(extracted_glcm_features)
extracted_glcm_features = (extracted_glcm_features - extracted_glcm_features.mean(axis=0)) / (extracted_glcm_features.std(axis=0) + 1e-8)

labels = np.array(labels)
# Out:
#   0%|          | 0/647 [00:00<?, ?it/s]

# %%
glrlmFeat = []
labels = []

for datum in tqdm(data[:(N_labels["benign"] + N_labels["malignant"])]): 
    
    datum_image = datum["image"].copy()
    datum_mask = datum["mask"].copy()
    
    glrlmFeatures = glrlm.RadiomicsGLRLM(GetImageFromArray(datum_image),
                                         GetImageFromArray(datum_mask),
                                         verbose=False)
    
    
    glrlmFeat.append(glrlmFeatures.execute())
    
    labels.append(datum["label"])


extracted_glrlm_features = []
keys = list(glrlmFeat[0].keys())

for datum in glrlmFeat:
    buff = []
    for key in keys:
        buff.append(datum[key])

    extracted_glrlm_features.append(buff)

extracted_glrlm_features = np.array(extracted_glrlm_features)
extracted_glrlm_features = (extracted_glrlm_features - extracted_glrlm_features.mean(axis=0)) / (extracted_glrlm_features.std(axis=0) + 1e-8)

labels = np.array(labels)
# Out:
#   0%|          | 0/647 [00:00<?, ?it/s]

# %%
gldmFeat = []
labels = []

for datum in tqdm(data[:(N_labels["benign"] + N_labels["malignant"])]): 
    
    datum_image = datum["image"].copy()
    datum_mask = datum["mask"].copy()
    
    gldmFeatures = gldm.RadiomicsGLDM(GetImageFromArray(datum_image),
                                      GetImageFromArray(datum_mask),
                                      verbose=False)
    
    
    gldmFeat.append(gldmFeatures.execute())
    
    labels.append(datum["label"])


extracted_gldm_features = []
keys = list(gldmFeat[0].keys())

for datum in gldmFeat:
    buff = []
    for key in keys:
        buff.append(datum[key])

    extracted_gldm_features.append(buff)

extracted_gldm_features = np.array(extracted_gldm_features)
extracted_gldm_features = (extracted_gldm_features - extracted_gldm_features.mean(axis=0)) / (extracted_gldm_features.std(axis=0) + 1e-8)

labels = np.array(labels)
# Out:
#   0%|          | 0/647 [00:00<?, ?it/s]

# %%
def pre_alpha_map(mu, omega):
    return ( omega * (1 - mu) ) / ( 2 * mu + 1e-8 )

def alpha_map(mu, omega):
    return 0.5 * np.sqrt( pre_alpha_map(mu, omega) + 0j)

def map2grayscaleimg(x):
    normalize_x = (x - x.min()) / (x.max() - x.min() + 1e-8)
    return (normalize_x * 255.0).astype(np.uint8)

# %%
index = 0
nakagami_alpha_maps = []
for datum in tqdm(data[:(N_labels["benign"] + N_labels["malignant"])]): 
    
    columns = np.where(datum["mask"].sum(axis=0))[0]
    rows = np.where(datum["mask"].sum(axis=1))[0]
    
    rows = [max([0, rows[0] - window_size[0] // 2]), min([128, rows[-1] + window_size[0] // 2 + 1])]
    columns = [max([0, columns[0] - window_size[1] // 2]), min([128, columns[-1] + window_size[1] // 2 + 1])]
            
    nakagami_mu, nakagami_omega = nakagami_maps[index][..., 0], nakagami_maps[index][..., 2]
    mask = datum["mask"][rows[0] :rows[1] , columns[0]:columns[1]]
    
    
    
    generated_alpha = alpha_map(nakagami_mu, nakagami_omega)
    
    generated_pre_alpha = map2grayscaleimg(pre_alpha_map(nakagami_mu, nakagami_omega))
    generated_alpha_real = map2grayscaleimg(np.real(generated_alpha))
    generated_alpha_imag = map2grayscaleimg(np.imag(generated_alpha))
    generated_alpha_abs = map2grayscaleimg(np.abs(generated_alpha))
    generated_alpha_angle = map2grayscaleimg(np.angle(generated_alpha))
    
    nakagami_alpha_map = [
        generated_pre_alpha,
        generated_alpha_real,
        generated_alpha_imag,
        generated_alpha_abs,
        generated_alpha_angle,
    ]
    
    nakagami_alpha_maps.append({"alpha_maps" : nakagami_alpha_map,
                                "mask" : mask,
                                "label" : datum["label"]
                               })
    
    index += 1
# Out:
#   0%|          | 0/647 [00:00<?, ?it/s]

# %%
glrlmFeats = []
labels = []

for datum in tqdm(nakagami_alpha_maps): 
    
    datum_alpha_maps = datum["alpha_maps"]
    
    glrlmFeat = []
    for datum_alpha_map in datum_alpha_maps:
        
        datum_image = datum_alpha_map.copy()
        datum_mask = datum["mask"].copy()
     
        glrlmFeatures = glrlm.RadiomicsGLRLM(GetImageFromArray(datum_image),
                                             GetImageFromArray(datum_mask),
                                             verbose=False)
        
        glrlmFeat.append(glrlmFeatures.execute())
    
    buffer1 = []
    for buffer2 in glrlmFeat:
        buffer1.append(np.array(list(buffer2.values())))
    
    glrlmFeats.append(np.concatenate(buffer1, axis=0))
    
    labels.append(datum["label"])

extracted_nakagami_features = np.array(glrlmFeats)
extracted_nakagami_features = (extracted_nakagami_features - extracted_nakagami_features.mean(axis=0)) / (extracted_nakagami_features.std(axis=0) + 1e-8)

labels = np.array(labels)
# Out:
#   0%|          | 0/647 [00:00<?, ?it/s]

# %% [markdown]
# ## Merge feature and feature reduction with PCA

# %%
extracted_features = [
    extracted_glcm_features,
    extracted_glrlm_features,
    extracted_gldm_features,
    extracted_nakagami_features,
]

extracted_features = np.concatenate(extracted_features, axis=-1)

print(f"Extracted features shape : {extracted_features.shape}")
# Out:
# Extracted features shape : (647, 134)

# %%
pca = PCA(n_components=16)
extracted_features = pca.fit_transform(extracted_features)

# %% [markdown]
# ## Train Validation Split

# %%
indices = np.random.permutation(len(labels))

# %%
n_train = int(0.8 * len(labels))

train_x, train_y = extracted_features[indices[:n_train]], labels[indices[:n_train]]
validation_x, validation_y = extracted_features[indices[n_train:]], labels[indices[n_train:]]

print(f"train input shape : {train_x.shape}")
print(f"validation input shape : {validation_x.shape}")
# Out:
# train input shape : (517, 16)
# validation input shape : (130, 16)

# %% [markdown]
# ## Multi-Layer Perceptron (MLP) Classifier

# %%
tf.keras.backend.clear_session()

mlp_save_path = os.path.join(result_path, "COMBINE_MLP")
os.makedirs(mlp_save_path, exist_ok=True)

epochs = 300 # number of epochs

# %%
## Define evaluating criterias

METRICS = [
      tf.keras.metrics.TruePositives(name='tp'),
      tf.keras.metrics.FalsePositives(name='fp'),
      tf.keras.metrics.TrueNegatives(name='tn'),
      tf.keras.metrics.FalseNegatives(name='fn'), 
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),
      tf.keras.metrics.AUC(name='auc'),
      tf.keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

# %%
# Define Callbacks

def LearningRateScheduler():
    def scheduler(epoch, lr):
        if epoch < 50:
            return lr
        else:
            if epoch % 30 == 0:
                lr = lr * tf.math.exp(-0.10)
        return lr
    return tf.keras.callbacks.LearningRateScheduler(scheduler)

show_progress = utils.ShowProgress(epochs) # for clean progress bar
best_weight = utils.BestModelWeights() # return best model weight on validation data

# %%
## Define model and compile it

mlp_model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(16,)),
    
    tf.keras.layers.Dense(256, activation="relu"),
    tf.keras.layers.Dense(256, activation="relu"),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(1, activation="sigmoid"),
])


mlp_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), # optimizer
                  loss=tf.keras.losses.BinaryCrossentropy(), # loss function
                  metrics=METRICS, # metrics for evaluate our model
                  )

# %%
#Train 
history = mlp_model.fit(train_x, train_y,
                        epochs=epochs,
                        validation_data=(validation_x, validation_y),
                        callbacks=[show_progress, best_weight, LearningRateScheduler()],
                        verbose=0 # When you want to use ShowProgress callback, you should set verbose to zero
                        )
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# Best weights is set, Best Epoch was : 20

# %% [markdown]
# ### Plot and print MLP results

# %%
print("Train Metrics : ")
_ = mlp_model.evaluate(train_x, train_y)
# Out:
# Train Metrics :
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3047 - tp: 120.0000 - fp: 23.0000 - tn: 335.0000 - fn: 39.0000 - accuracy: 0.8801 - precision: 0.8392 - recall: 0.7547 - auc: 0.9392 - prc: 0.8963

# %%
print("Validation Metrics : ")
_ = mlp_model.evaluate(validation_x, validation_y)
# Out:
# Validation Metrics :
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4301 - tp: 37.0000 - fp: 6.0000 - tn: 73.0000 - fn: 14.0000 - accuracy: 0.8462 - precision: 0.8605 - recall: 0.7255 - auc: 0.8902 - prc: 0.8589

# %%
save_filename = os.path.join(mlp_save_path, "criteria_over_epoch.jpg")

utils.plot_metrics(history)
plt.savefig(save_filename, dpi=150, bbox_inches="tight")

# %%
save_filename = os.path.join(mlp_save_path, "train_val_roc.jpg")

plt.figure(figsize=(5,5))
utils.plot_roc("Train Baseline",
               train_y,
               mlp_model.predict(train_x),
               color=colors[0])
utils.plot_roc("Test Baseline",
                validation_y,
                mlp_model.predict(validation_x),
                color=colors[1],
                linestyle='--')

plt.legend(loc='lower right');
plt.savefig(save_filename, dpi=150, bbox_inches="tight")
# Out:
# 17/17 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step

# %%
save_filename = os.path.join(mlp_save_path, "train_val_prc.jpg")

plt.figure(figsize=(5,5))
utils.plot_prc("Train Baseline",
               train_y,
               mlp_model.predict(train_x),
               color=colors[0])
utils.plot_prc("Test Baseline",
               validation_y,
               mlp_model.predict(validation_x),
               color=colors[1],
               linestyle='--')

plt.legend(loc='lower left');
plt.savefig(save_filename, dpi=150, bbox_inches="tight")
# Out:
# 17/17 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 2ms/step

# %%
save_filename = os.path.join(mlp_save_path, "train_val_confusionmatrix.jpg")

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
utils.plot_cm("Train",
              train_y,
              mlp_model.predict(train_x))
plt.subplot(1,2,2)
utils.plot_cm("Validation",
              validation_y,
              mlp_model.predict(validation_x))

plt.savefig(save_filename, dpi=150, bbox_inches="tight")
# Out:
# 17/17 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step

# %% [markdown]
# ## K-Nearest Neighbors (KNN) Classifier

# %%
knn_save_path = os.path.join(result_path, "COMBINE_KNN")
os.makedirs(knn_save_path, exist_ok=True)

# %%
knn_model = KNeighborsClassifier(n_neighbors=5)

# %%
knn_model.fit(train_x, train_y)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ### Plot and print KNN results

# %%
predicted = knn_model.predict_proba(train_x)[:,1]
fpr, tpr, thresholds = sklearn.metrics.roc_curve(train_y, predicted)
cm = sklearn.metrics.confusion_matrix(train_y, (predicted > 0.5).astype(np.int32))

knn_metrics = {
    "accuarcy": sklearn.metrics.accuracy_score(train_y, (predicted > 0.5).astype(np.int32)),
    "recall": sklearn.metrics.recall_score(train_y, (predicted > 0.5).astype(np.int32)),
    "precision": sklearn.metrics.precision_score(train_y, (predicted > 0.5).astype(np.int32)),
    "auc": sklearn.metrics.auc(fpr, tpr),
    "prc": sklearn.metrics.average_precision_score(train_y, predicted),
    "tp": cm[0,0],
    "fp": cm[0,1],
    "fn": cm[1,0],
    "tn": cm[1,1],
}

print("Train Metrics : ")
print(knn_metrics)
# Out:
# Train Metrics :
# {'accuarcy': 0.8723404255319149, 'recall': 0.7547169811320755, 'precision': 0.8163265306122449, 'auc': 0.9441955658620569, 'prc': 0.8571150894274677, 'tp': 331, 'fp': 27, 'fn': 39, 'tn': 120}

# %%
predicted = knn_model.predict_proba(validation_x)[:,1]
fpr, tpr, thresholds = sklearn.metrics.roc_curve(validation_y, predicted)
val_cm = sklearn.metrics.confusion_matrix(validation_y, (predicted > 0.5).astype(np.int32))

knn_metrics = {
    "val_accuarcy": sklearn.metrics.accuracy_score(validation_y, (predicted > 0.5).astype(np.int32)),
    "val_recall": sklearn.metrics.recall_score(validation_y, (predicted > 0.5).astype(np.int32)),
    "val_precision": sklearn.metrics.precision_score(validation_y, (predicted > 0.5).astype(np.int32)),
    "val_auc": sklearn.metrics.auc(fpr, tpr),
    "val_prc": sklearn.metrics.average_precision_score(validation_y, predicted),
    "val_tp": val_cm[0,0],
    "val_fp": val_cm[0,1],
    "val_fn": val_cm[1,0],
    "val_tn": val_cm[1,1],
}

print("Validation Metrics : ")
print(knn_metrics)
# Out:
# Validation Metrics :
# {'val_accuarcy': 0.7923076923076923, 'val_recall': 0.6862745098039216, 'val_precision': 0.7608695652173914, 'val_auc': 0.8476048647307024, 'val_prc': 0.796565844779973, 'val_tp': 68, 'val_fp': 11, 'val_fn': 16, 'val_tn': 35}

# %%
save_filename = os.path.join(knn_save_path, "train_val_roc.jpg")

plt.figure(figsize=(5,5))
utils.plot_roc("Train Baseline",
               train_y,
               knn_model.predict_proba(train_x)[:,1],
               color=colors[0])
utils.plot_roc("Test Baseline",
                validation_y,
                knn_model.predict_proba(validation_x)[:,1],
                color=colors[1],
                linestyle='--')

plt.legend(loc='lower right');
plt.savefig(save_filename, dpi=150, bbox_inches="tight")

# %%
save_filename = os.path.join(knn_save_path, "train_val_prc.jpg")

plt.figure(figsize=(5,5))
utils.plot_prc("Train Baseline",
               train_y,
               knn_model.predict_proba(train_x)[:,1],
               color=colors[0])
utils.plot_prc("Test Baseline",
               validation_y,
               knn_model.predict_proba(validation_x)[:,1],
               color=colors[1],
               linestyle='--')

plt.legend(loc='lower left');
plt.savefig(save_filename, dpi=150, bbox_inches="tight")

# %%
save_filename = os.path.join(knn_save_path, "train_val_confusionmatrix.jpg")

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
utils.plot_cm("Train",
              train_y,
              knn_model.predict_proba(train_x)[:,1],
             )
plt.subplot(1,2,2)
utils.plot_cm("Validation",
              validation_y,
              knn_model.predict_proba(validation_x)[:,1],
             )

plt.savefig(save_filename, dpi=150, bbox_inches="tight")

# %% [markdown]
# ## Linear Support Vector Machine (SVM) Classifier

# %%
lsvm_save_path = os.path.join(result_path, "COMBINE_LSVM")
os.makedirs(lsvm_save_path, exist_ok=True)

# %%
lsvm_model = SVC(probability=True, kernel='linear')

# %%
lsvm_model.fit(train_x, train_y)
# Out:
# SVC(kernel='linear', probability=True)

# %% [markdown]
# ### Plot and print SVM results

# %%
predicted = lsvm_model.predict_proba(train_x)[:,1]
cm = sklearn.metrics.confusion_matrix(train_y, (predicted > 0.5).astype(np.int32))

lsvm_metrics = {
    "accuarcy": sklearn.metrics.accuracy_score(train_y, (predicted > 0.5).astype(np.int32)),
    "recall": sklearn.metrics.recall_score(train_y, (predicted > 0.5).astype(np.int32)),
    "precision": sklearn.metrics.precision_score(train_y, (predicted > 0.5).astype(np.int32)),
    "auc": sklearn.metrics.auc(fpr, tpr),
    "prc": sklearn.metrics.average_precision_score(train_y, predicted),
    "tp": cm[0,0],
    "fp": cm[0,1],
    "fn": cm[1,0],
    "tn": cm[1,1],
}

print("Train Metrics : ")
print(lsvm_metrics)
# Out:
# Train Metrics :
# {'accuarcy': 0.8626692456479691, 'recall': 0.7295597484276729, 'precision': 0.8055555555555556, 'auc': 0.8476048647307024, 'prc': 0.8382933490145392, 'tp': 330, 'fp': 28, 'fn': 43, 'tn': 116}

# %%
predicted = lsvm_model.predict_proba(validation_x)[:,1]
val_cm = sklearn.metrics.confusion_matrix(validation_y, (predicted > 0.5).astype(np.int32))

lsvm_metrics = {
    "val_accuarcy": sklearn.metrics.accuracy_score(validation_y, (predicted > 0.5).astype(np.int32)),
    "val_recall": sklearn.metrics.recall_score(validation_y, (predicted > 0.5).astype(np.int32)),
    "val_precision": sklearn.metrics.precision_score(validation_y, (predicted > 0.5).astype(np.int32)),
    "val_auc": sklearn.metrics.auc(fpr, tpr),
    "val_prc": sklearn.metrics.average_precision_score(validation_y, predicted),
    "val_tp": val_cm[0,0],
    "val_fp": val_cm[0,1],
    "val_fn": val_cm[1,0],
    "val_tn": val_cm[1,1],
}

print("Validation Metrics : ")
print(lsvm_metrics)
# Out:
# Validation Metrics :
# {'val_accuarcy': 0.7923076923076923, 'val_recall': 0.6274509803921569, 'val_precision': 0.8, 'val_auc': 0.8476048647307024, 'val_prc': 0.8209401130609744, 'val_tp': 71, 'val_fp': 8, 'val_fn': 19, 'val_tn': 32}

# %%
save_filename = os.path.join(lsvm_save_path, "train_val_roc.jpg")

plt.figure(figsize=(5,5))
utils.plot_roc("Train Baseline",
               train_y,
               lsvm_model.predict_proba(train_x)[:,1],
               color=colors[0])
utils.plot_roc("Test Baseline",
                validation_y,
                lsvm_model.predict_proba(validation_x)[:,1],
                color=colors[1],
                linestyle='--')

plt.legend(loc='lower right');
plt.savefig(save_filename, dpi=150, bbox_inches="tight")

# %%
save_filename = os.path.join(lsvm_save_path, "train_val_prc.jpg")

plt.figure(figsize=(5,5))
utils.plot_prc("Train Baseline",
               train_y,
               lsvm_model.predict_proba(train_x)[:,1],
               color=colors[0])
utils.plot_prc("Test Baseline",
               validation_y,
               lsvm_model.predict_proba(validation_x)[:,1],
               color=colors[1],
               linestyle='--')

plt.legend(loc='lower left');
plt.savefig(save_filename, dpi=150, bbox_inches="tight")

# %%
save_filename = os.path.join(lsvm_save_path, "train_val_confusionmatrix.jpg")

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
utils.plot_cm("Train",
              train_y,
              lsvm_model.predict_proba(train_x)[:,1],
             )
plt.subplot(1,2,2)
utils.plot_cm("Validation",
              validation_y,
              lsvm_model.predict_proba(validation_x)[:,1],
             )

plt.savefig(save_filename, dpi=150, bbox_inches="tight")

# %% [markdown]
# ## RBF Support Vector Machine (SVM) Classifier

# %%
nlsvm_save_path = os.path.join(result_path, "COMBINE_NLSVM")
os.makedirs(nlsvm_save_path, exist_ok=True)

# %%
nlsvm_model = SVC(probability=True, kernel='rbf')

# %%
nlsvm_model.fit(train_x, train_y)
# Out:
# SVC(probability=True)

# %% [markdown]
# ### Plot and print SVM results

# %%
predicted = nlsvm_model.predict_proba(train_x)[:,1]
cm = sklearn.metrics.confusion_matrix(train_y, (predicted > 0.5).astype(np.int32))

nlsvm_metrics = {
    "accuarcy": sklearn.metrics.accuracy_score(train_y, (predicted > 0.5).astype(np.int32)),
    "recall": sklearn.metrics.recall_score(train_y, (predicted > 0.5).astype(np.int32)),
    "precision": sklearn.metrics.precision_score(train_y, (predicted > 0.5).astype(np.int32)),
    "auc": sklearn.metrics.auc(fpr, tpr),
    "prc": sklearn.metrics.average_precision_score(train_y, predicted),
    "tp": cm[0,0],
    "fp": cm[0,1],
    "fn": cm[1,0],
    "tn": cm[1,1],
}

print("Train Metrics : ")
print(nlsvm_metrics)
# Out:
# Train Metrics :
# {'accuarcy': 0.8781431334622823, 'recall': 0.7295597484276729, 'precision': 0.8529411764705882, 'auc': 0.8476048647307024, 'prc': 0.894088621628709, 'tp': 338, 'fp': 20, 'fn': 43, 'tn': 116}

# %%
predicted = nlsvm_model.predict_proba(validation_x)[:,1]
val_cm = sklearn.metrics.confusion_matrix(validation_y, (predicted > 0.5).astype(np.int32))

nlsvm_metrics = {
    "val_accuarcy": sklearn.metrics.accuracy_score(validation_y, (predicted > 0.5).astype(np.int32)),
    "val_recall": sklearn.metrics.recall_score(validation_y, (predicted > 0.5).astype(np.int32)),
    "val_precision": sklearn.metrics.precision_score(validation_y, (predicted > 0.5).astype(np.int32)),
    "val_auc": sklearn.metrics.auc(fpr, tpr),
    "val_prc": sklearn.metrics.average_precision_score(validation_y, predicted),
    "val_tp": val_cm[0,0],
    "val_fp": val_cm[0,1],
    "val_fn": val_cm[1,0],
    "val_tn": val_cm[1,1],
}

print("Validation Metrics : ")
print(nlsvm_metrics)
# Out:
# Validation Metrics :
# {'val_accuarcy': 0.7846153846153846, 'val_recall': 0.6274509803921569, 'val_precision': 0.7804878048780488, 'val_auc': 0.8476048647307024, 'val_prc': 0.8479926402110902, 'val_tp': 70, 'val_fp': 9, 'val_fn': 19, 'val_tn': 32}

# %%
save_filename = os.path.join(nlsvm_save_path, "train_val_roc.jpg")

plt.figure(figsize=(5,5))
utils.plot_roc("Train Baseline",
               train_y,
               nlsvm_model.predict_proba(train_x)[:,1],
               color=colors[0])
utils.plot_roc("Test Baseline",
                validation_y,
                nlsvm_model.predict_proba(validation_x)[:,1],
                color=colors[1],
                linestyle='--')

plt.legend(loc='lower right');
plt.savefig(save_filename, dpi=150, bbox_inches="tight")

# %%
save_filename = os.path.join(nlsvm_save_path, "train_val_prc.jpg")

plt.figure(figsize=(5,5))
utils.plot_prc("Train Baseline",
               train_y,
               nlsvm_model.predict_proba(train_x)[:,1],
               color=colors[0])
utils.plot_prc("Test Baseline",
               validation_y,
               nlsvm_model.predict_proba(validation_x)[:,1],
               color=colors[1],
               linestyle='--')

plt.legend(loc='lower left');
plt.savefig(save_filename, dpi=150, bbox_inches="tight")

# %%
save_filename = os.path.join(nlsvm_save_path, "train_val_confusionmatrix.jpg")

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
utils.plot_cm("Train",
              train_y,
              nlsvm_model.predict_proba(train_x)[:,1],
             )
plt.subplot(1,2,2)
utils.plot_cm("Validation",
              validation_y,
              nlsvm_model.predict_proba(validation_x)[:,1],
             )

plt.savefig(save_filename, dpi=150, bbox_inches="tight")

# %% [markdown]
# ## Polynomial Support Vector Machine (SVM) Classifier

# %%
plsvm_save_path = os.path.join(result_path, "COMBINE_PLSVM")
os.makedirs(plsvm_save_path, exist_ok=True)

# %%
plsvm_model = SVC(probability=True, kernel='poly', degree=3)

# %%
plsvm_model.fit(train_x, train_y)
# Out:
# SVC(kernel='poly', probability=True)

# %% [markdown]
# ### Plot and print SVM results

# %%
predicted = plsvm_model.predict_proba(train_x)[:,1]
cm = sklearn.metrics.confusion_matrix(train_y, (predicted > 0.5).astype(np.int32))

plsvm_metrics = {
    "accuarcy": sklearn.metrics.accuracy_score(train_y, (predicted > 0.5).astype(np.int32)),
    "recall": sklearn.metrics.recall_score(train_y, (predicted > 0.5).astype(np.int32)),
    "precision": sklearn.metrics.precision_score(train_y, (predicted > 0.5).astype(np.int32)),
    "auc": sklearn.metrics.auc(fpr, tpr),
    "prc": sklearn.metrics.average_precision_score(train_y, predicted),
    "tp": cm[0,0],
    "fp": cm[0,1],
    "fn": cm[1,0],
    "tn": cm[1,1],
}

print("Train Metrics : ")
print(plsvm_metrics)
# Out:
# Train Metrics :
# {'accuarcy': 0.7794970986460348, 'recall': 0.2830188679245283, 'precision': 1.0, 'auc': 0.8476048647307024, 'prc': 0.8886514233057012, 'tp': 358, 'fp': 0, 'fn': 114, 'tn': 45}

# %%
predicted = plsvm_model.predict_proba(validation_x)[:,1]
val_cm = sklearn.metrics.confusion_matrix(validation_y, (predicted > 0.5).astype(np.int32))

plsvm_metrics = {
    "val_accuarcy": sklearn.metrics.accuracy_score(validation_y, (predicted > 0.5).astype(np.int32)),
    "val_recall": sklearn.metrics.recall_score(validation_y, (predicted > 0.5).astype(np.int32)),
    "val_precision": sklearn.metrics.precision_score(validation_y, (predicted > 0.5).astype(np.int32)),
    "val_auc": sklearn.metrics.auc(fpr, tpr),
    "val_prc": sklearn.metrics.average_precision_score(validation_y, predicted),
    "val_tp": val_cm[0,0],
    "val_fp": val_cm[0,1],
    "val_fn": val_cm[1,0],
    "val_tn": val_cm[1,1],
}

print("Validation Metrics : ")
print(plsvm_metrics)
# Out:
# Validation Metrics :
# {'val_accuarcy': 0.6923076923076923, 'val_recall': 0.23529411764705882, 'val_precision': 0.9230769230769231, 'val_auc': 0.8476048647307024, 'val_prc': 0.8031232538253783, 'val_tp': 78, 'val_fp': 1, 'val_fn': 39, 'val_tn': 12}

# %%
save_filename = os.path.join(plsvm_save_path, "train_val_roc.jpg")

plt.figure(figsize=(5,5))
utils.plot_roc("Train Baseline",
               train_y,
               plsvm_model.predict_proba(train_x)[:,1],
               color=colors[0])
utils.plot_roc("Test Baseline",
                validation_y,
                plsvm_model.predict_proba(validation_x)[:,1],
                color=colors[1],
                linestyle='--')

plt.legend(loc='lower right');
plt.savefig(save_filename, dpi=150, bbox_inches="tight")

# %%
save_filename = os.path.join(plsvm_save_path, "train_val_prc.jpg")

plt.figure(figsize=(5,5))
utils.plot_prc("Train Baseline",
               train_y,
               plsvm_model.predict_proba(train_x)[:,1],
               color=colors[0])
utils.plot_prc("Test Baseline",
               validation_y,
               plsvm_model.predict_proba(validation_x)[:,1],
               color=colors[1],
               linestyle='--')

plt.legend(loc='lower left');
plt.savefig(save_filename, dpi=150, bbox_inches="tight")

# %%
save_filename = os.path.join(plsvm_save_path, "train_val_confusionmatrix.jpg")

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
utils.plot_cm("Train",
              train_y,
              plsvm_model.predict_proba(train_x)[:,1],
             )
plt.subplot(1,2,2)
utils.plot_cm("Validation",
              validation_y,
              plsvm_model.predict_proba(validation_x)[:,1],
             )

plt.savefig(save_filename, dpi=150, bbox_inches="tight")

# %% [markdown]
# ## Plot all Validation ROC and PRC curve together

# %%
save_filename = os.path.join(result_path, "val_roc_combine.jpg")

plt.figure(figsize=(5,5))
utils.plot_roc("MLP",
               validation_y,
               mlp_model.predict(validation_x),
               color=colors[0])

utils.plot_roc("KNN",
                validation_y,
                knn_model.predict_proba(validation_x)[:,1],
                color=colors[1],
                linestyle='--')

utils.plot_roc("Linear SVM",
                validation_y,
                lsvm_model.predict_proba(validation_x)[:,1],
                color=colors[2],
                linestyle='-')

utils.plot_roc("RBF SVM",
                validation_y,
                nlsvm_model.predict_proba(validation_x)[:,1],
                color=colors[3],
                linestyle='-.')

utils.plot_roc("Poly SVM",
                validation_y,
                plsvm_model.predict_proba(validation_x)[:,1],
                color=colors[4],
                linestyle=':')

plt.legend(loc='lower right');
plt.savefig(save_filename, dpi=150, bbox_inches="tight")
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %%
save_filename = os.path.join(result_path, "val_prc_combine.jpg")

plt.figure(figsize=(5,5))
utils.plot_prc("MLP",
               validation_y,
               mlp_model.predict(validation_x),
               color=colors[0])

utils.plot_prc("KNN",
                validation_y,
                knn_model.predict_proba(validation_x)[:,1],
                color=colors[1],
                linestyle='--')

utils.plot_prc("Linear SVM",
                validation_y,
                lsvm_model.predict_proba(validation_x)[:,1],
                color=colors[2],
                linestyle='-')

utils.plot_prc("RBF SVM",
                validation_y,
                nlsvm_model.predict_proba(validation_x)[:,1],
                color=colors[3],
                linestyle='-.')

utils.plot_prc("Poly SVM",
                validation_y,
                plsvm_model.predict_proba(validation_x)[:,1],
                color=colors[4],
                linestyle=':')

plt.legend(loc='lower left');
plt.savefig(save_filename, dpi=150, bbox_inches="tight")
# Out:
# 5/5 [==============================] - 0s 2ms/step
